# %%
import requests

url = "http://127.0.0.1:5000/predict"

data = {
    "day_type": "Weekend",
    "transport_mode": "EV",
    "distance_km": 5.0,
    "electricity_kwh": 10.0,
    "renewable_usage_pct": 50,
    "food_type": "Non-Veg",
    "screen_time_hours": 2.5,
    "waste_generated_kg": 1.2,
    "eco_actions": 1
}

response = requests.post(url, json=data)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'carbon_footprint_kg': 11.101234436035156}
